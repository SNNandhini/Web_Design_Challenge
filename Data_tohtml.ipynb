# %%
import pandas as pd

# %%
data = pd.read_csv("./Resources/cities.csv")

# %%
data
# Out:
#      City_ID            City  Cloudiness Country        Date  Humidity  \
# 0          0       Ilulissat         100      GL  1665622909        64
# 1          1          Albany         100      US  1665622909        67
# 2          2         Mataura           3      NZ  1665622909        43
# 3          3           Avera         100      US  1665622910        98
# 4          4      Nikolskoye          66      RU  1665622910        83
# ..       ...             ...         ...     ...         ...       ...
# 496      496  Preobrazheniye         100      RU  1665623080        61
# 497      497   San Cristobal          97      VE  1665623080        95
# 498      498        Linjiang         100      CN  1665623081        62
# 499      499            Nuuk          40      GL  1665622836        86
# 500      500       Stuttgart          13      DE  1665623081        71
#
#          Lat       Lng  Max Temp  Wind Speed
# 0    69.2167  -51.1000     28.42        5.75
# ...

# %%
data.to_html("source_data.html",index=False)
